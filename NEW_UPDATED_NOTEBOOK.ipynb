# %% [markdown]
# ### Important library

# %%
import math
import random
import pandas as pd

# %% [markdown]
# ### Read dataset

# %%
#dataset = pd.read_csv("iris.csv", header = None)
dataset = pd.read_csv("iris.csv")
dataset.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
# Get unique classes
classes = list(set(dataset['Name'])) 
print('classes:',classes)

number_of_class = len(classes)

# Encode the 'Name' into numeric 
dataset = dataset.replace('Iris-setosa',0)
dataset = dataset.replace('Iris-versicolor',1)
dataset = dataset.replace('Iris-virginica',2)

print('\nnumber_of_records:',len(dataset))
# Out:
# classes: ['Iris-virginica', 'Iris-versicolor', 'Iris-setosa']
#
# number_of_records: 150

# %% [markdown]
# ### Shuffle && Split into training and testing dataset

# %%
# Getting random indexes
indexes = random.sample(range(0, 150), 150)

training_dataset = []
testing_dataset = []

# Splting into training and testing
for i in range(100):
    training_dataset.append(dataset.iloc[indexes[i]])
    
for i in range(100,150):
    testing_dataset.append(dataset.iloc[indexes[i]])

# %% [markdown]
# ### KNN function

# %%
def knn(training_dataset, test, k):
    
    # Euclidean Distance
    
    # ED = list(np.sqrt(np.sum(np.square(training_dataset[:,0:-1] - test[0:-1]), axis = 1)))
    ED = []
    for i in range(len(training_dataset)):
        
        add = 0.0
        for j in range(4):
            add += ((training_dataset[i][j]-test[j])**2)
            
        ED.append(math.sqrt(add))
    
    sorted_ED = sorted(ED)
    
    KNN = []
    for i in range(k):
        index = ED.index(sorted_ED[i])
        KNN.append(training_dataset[index][-1])
    return KNN

# %% [markdown]
# ### Function call

# %%
k = 5

# Creating new Datafra
result = pd.DataFrame(columns=['sepal_length','sepal_width','petal_length','petal_width',
                               'predicted_class','actual_class','neighbours(K)','Iris-setosa',
                               'Iris-versicolor', 'Iris-virginica'])

for i in range(len(testing_dataset)):
    KNN = knn(training_dataset, testing_dataset[i], k)
    
    setosa     = 0
    versicolor = 0
    virginica  = 0
    
    for element in KNN:

        if element == 0:
            setosa += 1
            
        elif element == 1:
            versicolor += 1 

        else:
            virginica += 1

            
    
    unique_counts = [setosa, versicolor, virginica]
    unique_values = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
    result.loc[i] = [testing_dataset[i][0], testing_dataset[i][1], testing_dataset[i][2],
                     testing_dataset[i][3], unique_values[int(unique_counts.index(max(unique_counts)))],
                     unique_values[int(testing_dataset[i][4])],k,setosa,versicolor,virginica]

# %% [markdown]
# ### Result

# %%
result
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  predicted_class  \
# 0            6.3          3.3           6.0          2.5   Iris-virginica
# 1            5.5          4.2           1.4          0.2      Iris-setosa
# 2            4.6          3.4           1.4          0.3      Iris-setosa
# 3            5.6          2.8           4.9          2.0   Iris-virginica
# 4            6.9          3.1           4.9          1.5  Iris-versicolor
# 5            4.8          3.1           1.6          0.2      Iris-setosa
# 6            5.2          2.7           3.9          1.4  Iris-versicolor
# 7            5.5          2.4           3.7          1.0  Iris-versicolor
# 8            5.8          2.6           4.0          1.2  Iris-versicolor
# 9            6.1          3.0           4.6          1.4  Iris-versicolor
# 10           6.6          2.9           4.6          1.3  Iris-versicolor
# 11           6.3          2.5           4.9          1.5   Iris-virginica
# 12           4.8          3.4           1.9          0.2      Iris-setosa
# 13           5.0          3.5           1.3          0.3      Iris-setosa
# 14           5.1          3.3           1.7          0.5      Iris-setosa
# 15           7.7          3.0           6.1          2.3   Iris-virginica
# 16           6.4          3.2           5.3          2.3   Iris-virginica
# 17           5.2          3.4           1.4          0.2      Iris-setosa
# 18           4.6          3.2           1.4          0.2      Iris-setosa
# 19           5.0          3.0           1.6          0.2      Iris-setosa
# 20           5.5          2.3           4.0          1.3  Iris-versicolor
# 21           6.5          3.0           5.5          1.8   Iris-virginica
# 22           6.2          2.2           4.5          1.5  Iris-versicolor
# 23           6.7          3.1           4.4          1.4  Iris-versicolor
# 24           5.7          2.9           4.2          1.3  Iris-versicolor
# 25           5.1          3.8           1.9          0.4      Iris-setosa
# 26           5.1          3.5           1.4          0.2      Iris-setosa
# 27           7.1          3.0           5.9          2.1   Iris-virginica
# 28           6.6          3.0           4.4          1.4  Iris-versicolor
# 29           5.4          3.9           1.3          0.4      Iris-setosa
# 30           7.3          2.9           6.3          1.8   Iris-virginica
# 31           6.4          2.8           5.6          2.1   Iris-virginica
# 32           5.4          3.0           4.5          1.5  Iris-versicolor
# 33           6.8          3.0           5.5          2.1   Iris-virginica
# 34           6.7          3.1           4.7          1.5  Iris-versicolor
# 35           5.1          3.8           1.5          0.3      Iris-setosa
# 36           6.0          2.2           5.0          1.5   Iris-virginica
# 37           4.9          2.4           3.3          1.0  Iris-versicolor
# 38           6.4          2.9           4.3          1.3  Iris-versicolor
# 39           5.1          3.5           1.4          0.3      Iris-setosa
# 40           4.9          3.1           1.5          0.1      Iris-setosa
# 41           5.2          3.5           1.5          0.2      Iris-setosa
# 42           6.1          2.8           4.7          1.2  Iris-versicolor
# 43           5.7          3.0           4.2          1.2  Iris-versicolor
# 44           5.6          2.5           3.9          1.1  Iris-versicolor
# 45           5.9          3.0           4.2          1.5  Iris-versicolor
# 46           6.3          3.3           4.7          1.6  Iris-versicolor
# 47           6.5          3.0           5.2          2.0   Iris-virginica
# 48           6.5          3.2           5.1          2.0   Iris-virginica
# 49           4.4          3.0           1.3          0.2      Iris-setosa
#
#        actual_class neighbours(K) Iris-setosa Iris-versicolor Iris-virginica
# 0    Iris-virginica             5           0               0              5
# 1       Iris-setosa             5           5               0              0
# 2       Iris-setosa             5           5               0              0
# 3    Iris-virginica             5           0               0              5
# 4   Iris-versicolor             5           0               5              0
# 5       Iris-setosa             5           5               0              0
# 6   Iris-versicolor             5           0               5              0
# 7   Iris-versicolor             5           0               5              0
# 8   Iris-versicolor             5           0               5              0
# 9   Iris-versicolor             5           0               4              1
# 10  Iris-versicolor             5           0               5              0
# 11  Iris-versicolor             5           0               1              4
# 12      Iris-setosa             5           5               0              0
# 13      Iris-setosa             5           5               0              0
# 14      Iris-setosa             5           5               0              0
# 15   Iris-virginica             5           0               0              5
# 16   Iris-virginica             5           0               0              5
# 17      Iris-setosa             5           5               0              0
# 18      Iris-setosa             5           5               0              0
# 19      Iris-setosa             5           5               0              0
# 20  Iris-versicolor             5           0               5              0
# 21   Iris-virginica             5           0               0              5
# 22  Iris-versicolor             5           0               3              2
# 23  Iris-versicolor             5           0               5              0
# 24  Iris-versicolor             5           0               5              0
# 25      Iris-setosa             5           5               0              0
# 26      Iris-setosa             5           5               0              0
# 27   Iris-virginica             5           0               0              5
# 28  Iris-versicolor             5           0               5              0
# 29      Iris-setosa             5           5               0              0
# 30   Iris-virginica             5           0               0              5
# 31   Iris-virginica             5           0               0              5
# 32  Iris-versicolor             5           0               5              0
# 33   Iris-virginica             5           0               0              5
# 34  Iris-versicolor             5           0               5              0
# 35      Iris-setosa             5           5               0              0
# 36   Iris-virginica             5           0               1              4
# 37  Iris-versicolor             5           0               5              0
# 38  Iris-versicolor             5           0               5              0
# 39      Iris-setosa             5           5               0              0
# 40      Iris-setosa             5           5               0              0
# 41      Iris-setosa             5           5               0              0
# 42  Iris-versicolor             5           0               5              0
# 43  Iris-versicolor             5           0               5              0
# 44  Iris-versicolor             5           0               5              0
# 45  Iris-versicolor             5           0               5              0
# 46  Iris-versicolor             5           0               3              2
# 47   Iris-virginica             5           0               1              4
# 48   Iris-virginica             5           0               1              4
# 49      Iris-setosa             5           5               0              0

# %% [markdown]
# ### Accuracy

# %%
accuracy_data = result['actual_class']==result['predicted_class']

true = 0
false = 0
for bool_value in accuracy_data:
    if(bool_value == True):
        true+=1
    else:
        false+=1

# %%
accuracy = true/len(accuracy_data)

# %%
accuracy
# Out:
# 0.98
